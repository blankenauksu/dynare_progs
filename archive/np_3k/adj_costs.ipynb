# %% [markdown]
# Here are the typeset versions of the capital adjustment cost specifications:
#
# 1. Quadratic adjustment costs:
#
#    $C(I_t, K_t) = \frac{\phi}{2} \left(\frac{I_t}{K_t} - \delta\right)^2 K_t$
#
#    where $I_t$ is investment, $K_t$ is the capital stock, $\delta$ is the depreciation rate, and $\phi$ is the adjustment cost parameter.
#
# 2. Asymmetric adjustment costs:
#
#    $C(I_t, K_t) = \begin{cases}
#    \frac{\phi^+}{2} \left(\frac{I_t}{K_t} - \delta\right)^2 K_t & \text{if } I_t > \delta K_t \\
#    \frac{\phi^-}{2} \left(\frac{I_t}{K_t} - \delta\right)^2 K_t & \text{if } I_t \leq \delta K_t
#    \end{cases}$
#
#    where $\phi^+$ and $\phi^-$ are the adjustment cost parameters for upward and downward adjustments, respectively.
#
# 3. Fixed adjustment costs:
#
#    $C(I_t, K_t) = F \cdot \mathbf{1}_{I_t \neq 0}$
#
#    where $F$ is the fixed cost and $\mathbf{1}_{I_t \neq 0}$ is an indicator function that equals 1 if investment is non-zero and 0 otherwise.
#
# 4. Kinked adjustment costs:
#
#    $C(I_t, K_t) = \frac{\phi}{2} \left(\frac{I_t}{K_t} - \delta\right)^2 K_t + F \cdot \mathbf{1}_{\left|\frac{I_t}{K_t} - \delta\right| > \bar{i}}$
#
#    where $\bar{i}$ is the threshold investment rate.
#
# These typeset equations should render correctly in a LaTeX environment or markdown with LaTeX support.

# %% [markdown]
# Yes, there are similar adjustment cost specifications for labor in economic models. These adjustment costs are introduced to capture the idea that changing the level of employment is costly for firms due to hiring, training, and firing costs. The most common specifications for labor adjustment costs are:
#
# 1. Quadratic adjustment costs:
#
#    $C(H_t, N_t) = \frac{\psi}{2} \left(\frac{H_t}{N_t} - \bar{g}\right)^2 N_t$
#
#    where $H_t$ is the number of hires, $N_t$ is the current level of employment, $\bar{g}$ is the steady-state growth rate of employment, and $\psi$ is the adjustment cost parameter.
#
# 2. Asymmetric adjustment costs:
#
#    $C(H_t, N_t) = \begin{cases}
#    \frac{\psi^+}{2} \left(\frac{H_t}{N_t} - \bar{g}\right)^2 N_t & \text{if } H_t > \bar{g} N_t \\
#    \frac{\psi^-}{2} \left(\frac{H_t}{N_t} - \bar{g}\right)^2 N_t & \text{if } H_t \leq \bar{g} N_t
#    \end{cases}$
#
#    where $\psi^+$ and $\psi^-$ are the adjustment cost parameters for upward and downward adjustments, respectively.
#
# 3. Fixed adjustment costs:
#
#    $C(H_t, N_t) = F \cdot \mathbf{1}_{H_t \neq 0}$
#
#    where $F$ is the fixed cost and $\mathbf{1}_{H_t \neq 0}$ is an indicator function that equals 1 if hiring is non-zero and 0 otherwise.
#
# 4. Hiring and firing costs:
#
#    $C(H_t, F_t, N_t) = \psi_H \frac{H_t^2}{2} + \psi_F \frac{F_t^2}{2}$
#
#    where $H_t$ is the number of hires, $F_t$ is the number of fires, and $\psi_H$ and $\psi_F$ are the adjustment cost parameters for hiring and firing, respectively.
#
# 5. Linex adjustment costs:
#
#    $C(H_t, N_t) = \frac{\psi}{\theta^2} \left[\exp\left(\theta\frac{H_t}{N_t}\right) - \theta\frac{H_t}{N_t} - 1\right] N_t$
#
#    where $\theta$ is a parameter that governs the asymmetry of the adjustment costs. This specification allows for asymmetric adjustment costs without the need for a piecewise function.
#
# These labor adjustment cost specifications can be incorporated into dynamic models of the labor market to study employment dynamics, wage setting, and the impact of various shocks and policies on labor market outcomes. The choice of specification depends on the research question and the empirical evidence on labor market adjustment costs.

# %% [markdown]
# One example of a paper that uses linex adjustment costs in the labor market is:
#
# Yashiv, E. (2000). The determinants of equilibrium unemployment. American Economic Review, 90(5), 1297-1322.
#
# In this paper, Yashiv introduces a labor market model with search and matching frictions and linex adjustment costs for hiring. The linex adjustment cost function is given by:
#
# $C(H_t, N_t) = \frac{\psi}{\theta^2} \left[\exp\left(\theta\frac{H_t}{N_t}\right) - \theta\frac{H_t}{N_t} - 1\right] N_t$
#
# where $H_t$ is the number of hires, $N_t$ is the current level of employment, and $\psi$ and $\theta$ are parameters governing the magnitude and asymmetry of the adjustment costs, respectively.
#
# The linex specification allows for asymmetric adjustment costs, with the degree of asymmetry determined by the parameter $\theta$. When $\theta > 0$, the marginal cost of hiring is increasing and convex, implying that it becomes increasingly costly for firms to expand employment. When $\theta < 0$, the marginal cost of hiring is increasing but concave, implying that the cost of expanding employment is less severe.
#
# Yashiv uses this specification to study the determinants of equilibrium unemployment and to analyze the impact of various shocks on labor market dynamics. The linex adjustment cost function is used to capture the idea that firms face asymmetric costs when adjusting their workforce, with the costs of expanding employment being different from the costs of reducing employment.
#
# The paper demonstrates that the inclusion of linex adjustment costs in the labor market model can help to explain several empirical observations, such as the persistence of unemployment and the asymmetric response of employment to positive and negative shocks.

# %% [markdown]
# To find the derivative of the linex cost function with respect to H, we can use the following rules:
#
# 1. The derivative of a constant term is 0.
# 2. The derivative of a linear term is the coefficient of the term.
# 3. The derivative of an exponential term $e^x$ is $e^x$.
# 4. The chain rule: If $f(x) = g(h(x))$, then $f'(x) = g'(h(x)) \cdot h'(x)$.
#
# Let's start with the linex cost function:
#
# $C(H_t, N_t) = \frac{\psi}{\theta^2} \left[\exp\left(\theta\frac{H_t}{N_t}\right) - \theta\frac{H_t}{N_t} - 1\right] N_t$
#
# To simplify the derivative, let's first focus on the term inside the square brackets and denote it as $f(H_t)$:
#
# $f(H_t) = \exp\left(\theta\frac{H_t}{N_t}\right) - \theta\frac{H_t}{N_t} - 1$
#
# Now, we can find the derivative of $f(H_t)$ with respect to $H_t$:
#
# $f'(H_t) = \exp\left(\theta\frac{H_t}{N_t}\right) \cdot \frac{\theta}{N_t} - \frac{\theta}{N_t}$
#
# Using the chain rule, we can find the derivative of the linex cost function with respect to $H_t$:
#
# $\frac{\partial C(H_t, N_t)}{\partial H_t} = \frac{\psi}{\theta^2} \cdot f'(H_t) \cdot N_t$
#
# Substituting the expression for $f'(H_t)$:
#
# $\frac{\partial C(H_t, N_t)}{\partial H_t} = \frac{\psi}{\theta^2} \cdot \left[\exp\left(\theta\frac{H_t}{N_t}\right) \cdot \frac{\theta}{N_t} - \frac{\theta}{N_t}\right] \cdot N_t$
#
# Simplifying the expression:
#
# $\frac{\partial C(H_t, N_t)}{\partial H_t} = \frac{\psi}{\theta} \cdot \left[\exp\left(\theta\frac{H_t}{N_t}\right) - 1\right]$
#
# Therefore, the derivative of the linex cost function with respect to $H_t$ is:
#
# $\frac{\partial C(H_t, N_t)}{\partial H_t} = \frac{\psi}{\theta} \cdot \left[\exp\left(\theta\frac{H_t}{N_t}\right) - 1\right]$
#
# This expression represents the marginal cost of hiring an additional worker, given the current level of employment and the linex adjustment cost parameters.

# %% [markdown]
# To find the derivative of the linex cost function with respect to $N_t$, we can use the product rule and the chain rule. Recall the linex cost function:
#
# $C(H_t, N_t) = \frac{\psi}{\theta^2} \left[\exp\left(\theta\frac{H_t}{N_t}\right) - \theta\frac{H_t}{N_t} - 1\right] N_t$
#
# Let's denote the term inside the square brackets as $f(N_t)$:
#
# $f(N_t) = \exp\left(\theta\frac{H_t}{N_t}\right) - \theta\frac{H_t}{N_t} - 1$
#
# Using the product rule, we can write:
#
# $\frac{\partial C(H_t, N_t)}{\partial N_t} = \frac{\psi}{\theta^2} \cdot \left[f(N_t) \cdot \frac{\partial N_t}{\partial N_t} + N_t \cdot \frac{\partial f(N_t)}{\partial N_t}\right]$
#
# Simplifying the first term:
#
# $\frac{\partial C(H_t, N_t)}{\partial N_t} = \frac{\psi}{\theta^2} \cdot \left[f(N_t) + N_t \cdot \frac{\partial f(N_t)}{\partial N_t}\right]$
#
# Now, let's find $\frac{\partial f(N_t)}{\partial N_t}$ using the chain rule:
#
# $\frac{\partial f(N_t)}{\partial N_t} = \exp\left(\theta\frac{H_t}{N_t}\right) \cdot \left(-\theta\frac{H_t}{N_t^2}\right) + \theta\frac{H_t}{N_t^2}$
#
# Simplifying:
#
# $\frac{\partial f(N_t)}{\partial N_t} = \frac{\theta H_t}{N_t^2} \cdot \left[1 - \exp\left(\theta\frac{H_t}{N_t}\right)\right]$
#
# Substituting this expression back into the derivative of $C(H_t, N_t)$ with respect to $N_t$:
#
# $\frac{\partial C(H_t, N_t)}{\partial N_t} = \frac{\psi}{\theta^2} \cdot \left[f(N_t) + N_t \cdot \frac{\theta H_t}{N_t^2} \cdot \left[1 - \exp\left(\theta\frac{H_t}{N_t}\right)\right]\right]$
#
# Expanding $f(N_t)$ and simplifying:
#
# $\frac{\partial C(H_t, N_t)}{\partial N_t} = \frac{\psi}{\theta^2} \cdot \left[\exp\left(\theta\frac{H_t}{N_t}\right) - \theta\frac{H_t}{N_t} - 1 + \frac{\theta H_t}{N_t} - \frac{\theta H_t}{N_t} \cdot \exp\left(\theta\frac{H_t}{N_t}\right)\right]$
#
# Further simplification yields:
#
# $\frac{\partial C(H_t, N_t)}{\partial N_t} = \frac{\psi}{\theta^2} \cdot \left[\exp\left(\theta\frac{H_t}{N_t}\right) \cdot \left(1 - \theta\frac{H_t}{N_t}\right) - 1\right]$
#
# This expression represents the marginal effect of a change in the current level of employment on the linex adjustment costs, given the number of hires and the linex adjustment cost parameters.

# %%
params = {
    'eps': 1.5,
    'tht': 1,
    'alf': .5,
    'bet': .9,
    'om_0': 1,
    'om_1': 1,
    'om_2': 1,
    'delt': .05
}

# %%
ss_shock = {
    'a_0': 0,
    'a_1': 0,
    'a_2': 0
}

# %%
shock_params = {
    'var_a_0': .5,
    'var_a_1': .6,
    'var_a_2': .7,
    'rho_a_0': .9,
    'rho_a_1': .9,
    'rho_a_2': .9
}

# %%
ss_params = {**params, **ss_shock}
model_params = {**params, **shock_params}
