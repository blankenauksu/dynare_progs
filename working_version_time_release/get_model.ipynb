# %%
#import pickle
#with open('pars.pickle', 'rb') as f:
#    pars = pickle.load(f)
lines3=[]

lines3.append('          [name=\'education spending\']' )
lines3.append('\n')
lines3.append('exp(Ge)=rat_ge*exp(Y)*exp(Ges);') 
lines3.append('\n')
lines3.append('\n')

lines3.append('          [name=\'other spending\']' )
lines3.append('\n')
lines3.append('exp(Gu)=rat_gu*exp(Y)*exp(Gus);')
lines3.append('\n')
lines3.append('\n')

lines3.append('          [name=\'find tau_s\']' )
lines3.append('\n')
lines3.append('exp(tau_S)=chi*exp(tau_L);')
lines3.append('\n')
lines3.append('\n')

lines3.append('          [name=\'Tau_L with government budget constraint\']' )
lines3.append('\n')
lines3.append('\n')
lines3.append('exp(tau_L)=(1-share_lump)*(exp(Ge)+exp(Gu))/((1-alfa)*exp(Y)+chi*(alfa*exp(Y)-deltak*exp(K)));')
lines3.append('\n')
lines3.append('\n')
lines3.append('exp(tau_Lump)=share_lump*(exp(Ge)+exp(Gu))/(nw+nr);')
#lines3.append('\n')
lines3.append('          [name=\'budget constraints\']' )
lines3.append('\n')
lines3.append('(exp(Ge)+exp(Gu))=exp(rev_L)+exp(rev_S)+exp(rev_Lump);')
lines3.append('\n')
lines3.append('\n')

lines3.append('          [name=\'output\']' )
lines3.append('\n')
lines3.append('exp(Y)=A*exp(K(-1))^alfa*exp(L)^(1-alfa)*exp((GY));')
lines3.append('\n')
lines3.append('\n')

lines3.append('          [name=\'wage\']' )
lines3.append('\n')
lines3.append('exp(w)=(1-alfa)*exp(Y)/exp(L);')
lines3.append('\n')
lines3.append('\n')

lines3.append('          [name=\'rental rate of capital\']' )
lines3.append('\n')
lines3.append('exp(rk)=alfa*exp(Y)/exp(K(-1));')
lines3.append('\n')
lines3.append('\n')

lines3.append('          [name=\'net return of capital\']' )
lines3.append('\n')
lines3.append('exp(rb)=(exp(rk)-deltak);')
lines3.append('\n')
lines3.append('\n')

lines3.append('          [name=\'goods market clearing\']' )
lines3.append('\n')
lines3.append('exp(Y)=exp(C)+exp(I)+exp(Ge)+exp(Gu);')
lines3.append('\n')
lines3.append('\n')

lines3.append('          [name=\'wage times hc\']' )
lines3.append('\n')
lines3.append('exp(wg_hc)=exp(w)*exp(hf);')
lines3.append('\n')
lines3.append('\n')

lines3.append('          [name=\'wage over L\']' )
lines3.append('\n')
lines3.append('exp(wg_L)=exp(w)*exp(L);')
lines3.append('\n')
lines3.append('\n')

for i in range(pars['a_n_b'][0]+1, pars['a_n_b'][0]+pars['a_n_p'][0]+ pars['a_n_es'][0]+pars['a_n_ls'][0]+1):
    str2='          [name=\'goverment spending age'+str(i)+'\']' 
    lines3.append(str2)
    lines3.append('\n')
    str1='exp(g'+str(i)+')=gj'+str(i)+'*exp(Ge);'
    #str1='exp(g'+str(i)+')=gj'+str(i)+'*exp(Ge)'; 
    lines3.append(str1)
    lines3.append('\n')
    lines3.append('\n')

lines3.append('          [name=\'education input\']' )
lines3.append('\n')
lines3.append('exp(e)=(')


for i in range(pars['a_n_b'][0]+1, pars['a_n_b'][0]+pars['a_n_p'][0]+ pars['a_n_es'][0]+pars['a_n_ls'][0]+1):
    if i<pars['a_n_b'][0]+pars['a_n_p'][0]+ pars['a_n_es'][0]+pars['a_n_ls'][0]:
       str1='eta'+str(i)+'*exp(g'+str(i)+'(-'+str(pars['a_n_b'][0]+pars['a_n_p'][0]+ pars['a_n_es'][0]+pars['a_n_ls'][0]-i+1)+'))^phi+' 
    else:
       str1='eta'+str(i)+'*exp(g'+str(i)+'(-'+str(pars['a_n_b'][0]+pars['a_n_p'][0]+ pars['a_n_es'][0]+pars['a_n_ls'][0]-i+1)+'))^phi)^(1/phi);' 

    lines3.append('\n')
    lines3.append(str1)  

lines3.append('\n')
lines3.append('\n')
lines3.append('          [name=\'parental human capital\']' )
lines3.append('\n')
str1='exp(hf)=bb*exp(e)^mu;'

lines3.append(str1)
lines3.append('\n')
lines3.append('\n')
for i in range(1,pars['p_nw'][0]+1):
    str2='          [name=\'human capital at period '+str(i)+' of work\']' 
    lines3.append(str2)
    lines3.append('\n')
    
    str1='exp(h'+str(i)+')=exp(hf(-'+str(i-1)+'))*(1-deltae)^'+str(i-1)+'+x'+str(i)+';'
    lines3.append(str1)
    lines3.append('\n')
    lines3.append('\n')   
    
    
for i in range(1,pars['p_nw'][0]+pars['p_nr'][0]+1):
    str1='beta'+str(i)+'*exp(c'+str(i)+')^(-theta)=beta'+str(i+1)+'*exp(c'+str(i+1)+'(+1))^(-theta)*(1+exp(rb(+1))*(1-exp(tau_S(+1))));' 
    str2='gama'+str(i)+'*exp(L'+str(i)+')^nu=exp(c'+str(i)+')^(-theta)*exp(w)*exp(h'+str(i)+')*(1-exp(tau_L));' 
    if i == 1:
        str3='s'+str(i)+'=exp(w)*exp(h'+str(i)+')*exp(L'+str(i)+')*(1-exp(tau_L))-exp(c'+str(i)+')-exp(tau_Lump);' 
    elif i <= pars['p_nw'][0]:
        str3='s'+str(i)+'=exp(w)*exp(h'+str(i)+')*exp(L'+str(i)+')*(1-exp(tau_L))+s'+str(i-1)+'(-1)*(1+exp(rb)*(1-exp(tau_S)))-exp(c'+str(i)+')-exp(tau_Lump);' 
    else:
        str3='s'+str(i)+'=s'+str(i-1)+'(-1)*(1+exp(rb)*(1-exp(tau_S)))-exp(c'+str(i)+')-exp(tau_Lump);' 
      
    
    if i > 1:
        str4='rev_S'+str(i)+'=s'+str(i-1)+'(-1)*(exp(rk)-deltak)*exp(tau_S);' 
 
    str5='exp(rev_L'+str(i)+')=exp(w)*exp(h'+str(i)+')*exp(L'+str(i)+')*exp(tau_L);'
    str6='exp(rev_Lump'+str(i)+')=exp(tau_Lump);'
    str1a='          [name=\'intertemporal optimization at period '+str(i)+' of work or retimement\']' 
    str2a='          [name=\'intratemporal optimization at period '+str(i)+' of work\']' 
    str3a='          [name=\'savings at period '+str(i)+' of work or retirement\']' 
    str5a='          [name=\'labor tax revemnue paid '+str(i)+' of work\']'
    str4a='          [name=\'capital tax revenus paid at period '+str(i)+' of work or retirement\']' 
    str6a='          [name=\'Lump sum tax paid at period '+str(i)+' of work or retirement\']' 
 #  % str7a=['          [name=\'Lump sum tax paid at period '+str(i)+'...final period of life\']']; 
    if i <=pars['p_nw'][0]:
        lines3.append(str2a)
        lines3.append('\n')
        lines3.append(str2)
        lines3.append('\n')
 
    
    if i<pars['p_nw'][0]+pars['p_nr'][0]:
        if i>1:
            lines3.append(str4a)
            lines3.append('\n')    
            lines3.append(str4)
            lines3.append('\n')
        lines3.append(str1a)
        lines3.append('\n')
        lines3.append(str1)
        lines3.append('\n')
        lines3.append(str3a)
        lines3.append('\n')
        lines3.append(str3)
        lines3.append('\n')
 
 #   %if v>1;
 #   %lines3.append(str4a)
 #   %lines3.append('\n')    
 #   %lines3.append(str4)
 #   %lines3.append('\n')
 #   %end;
    if i <= pars['p_nw'][0]:
        lines3.append(str5a)
        lines3.append('\n')
        lines3.append(str5)
        lines3.append('\n')
 
    lines3.append(str6a)
    lines3.append('\n')    
    lines3.append(str6)
    lines3.append('\n')
    lines3.append('\n')

  
lines3.append('          [name=\'total consumption\']' )
lines3.append('\n')
lines3.append('exp(C)=')
for i in range(1,pars['p_nw'][0]+pars['p_nr'][0]+1):
    if i<pars['p_nw'][0]+pars['p_nr'][0]:
        str1='exp(c'+str(i)+')+' 
    else:
        str1='exp(c'+str(i)+');' 

    lines3.append('\n')
    lines3.append(str1)  

lines3.append('\n')
lines3.append('\n')

lines3.append('          [name=\'law of motion\']' )
lines3.append('\n')
lines3.append('exp(K)=(1-deltak)*exp(K(-1))+exp(I);')
lines3.append('\n')
lines3.append('\n')


lines3.append('          [name=\'total labor input\']' )
lines3.append('\n')
lines3.append('exp(L)=')

for i in range(1,pars['p_nw'][0]+1):
    if i<pars['p_nw'][0]:
     str1='exp(L'+str(i)+')*exp(h'+str(i)+')+'
    else:
     str1='exp(L'+str(i)+')*exp(h'+str(i)+');' 

    lines3.append('\n')
    lines3.append(str1)  

lines3.append('\n')
lines3.append('\n')

lines3.append('          [name=\'total hours worked (labor market clearing)\']' )
lines3.append('\n')
lines3.append('exp(Tot_labor)=')
for i in range(1,pars['p_nw'][0]+1):
    if i<pars['p_nw'][0]:
        str1='exp(L'+str(i)+')+' 
    else:
     str1='exp(L'+str(i)+');' 

    lines3.append('\n')
    lines3.append(str1)  

lines3.append('\n')
lines3.append('\n')

lines3.append('          [name= \'total human capital\']' )
lines3.append('\n')
lines3.append('exp(Tot_hc)=')
for i in range(1,pars['p_nw'][0]+1):
    if i<pars['p_nw'][0]:
        str1='exp(h'+str(i)+')+' 
    else:
        str1='exp(h'+str(i)+');' 
    lines3.append('\n')
    lines3.append(str1)  

lines3.append('\n')
lines3.append('\n')

lines3.append('          [name=\'capital market clearing\']' )
lines3.append('\n')
lines3.append('exp(K)=')
for i in range(1,pars['p_nw'][0]+pars['p_nr'][0]):
    if i<pars['p_nw'][0]+pars['p_nr'][0]-1:
        str1='s'+str(i)+'+' 
    else:
        str1='s'+str(i)+';'

    lines3.append('\n')
    lines3.append(str1)  
lines3.append('\n')
lines3.append('\n')

lines3.append('          [name=\'total revenue from labor tax\']' )
lines3.append('\n')
lines3.append('exp(rev_L)=')
for i in range(1,pars['p_nw'][0]+1):
    if i<pars['p_nw'][0]:
        str1='exp(rev_L'+str(i)+')+' 
    else:
        str1='exp(rev_L'+str(i)+');'
    lines3.append('\n')
    lines3.append(str1)  
lines3.append('\n')
lines3.append('\n')

lines3.append('          [name=\'total revenue from capital tax\']' )
lines3.append('\n')
lines3.append('exp(rev_S)=')
for i in range(2,pars['p_nw'][0]+pars['p_nr'][0]+1):
    if i<pars['p_nw'][0]+pars['p_nr'][0]:
        str1='rev_S'+str(i)+'+' 
    else:
        str1='rev_S'+str(i)+';'

    lines3.append('\n')
    lines3.append(str1)  

lines3.append('\n')
lines3.append('\n')
lines3.append('          [name=\'total revenue from lump sum tax\']' )
lines3.append('\n')
lines3.append('exp(rev_Lump)=')
for i in range(1,pars['p_nw'][0]+pars['p_nr'][0]+1):
    if i<pars['p_nw'][0]+pars['p_nr'][0]:
        str1='exp(rev_Lump'+str(i)+')+' 
    else:
        str1='exp(rev_Lump'+str(i)+');'

    lines3.append('\n')
    lines3.append(str1)  


lines3.append('\n')
lines3.append('\n')

lines3.append('Ges=rho_Ge*Ges(-1)+Ge_shock;')
lines3.append('\n')
lines3.append('\n')
lines3.append('Gus=rho_Gu*Gus(-1)+Gu_shock;')
lines3.append('\n')
lines3.append('\n')
lines3.append('GY=rho_GY*GY(-1)+GY_shock;')
lines3.append('\n')
lines3.append('\n')


with open('t_model.m', 'w') as f:
    f.writelines(lines3)
